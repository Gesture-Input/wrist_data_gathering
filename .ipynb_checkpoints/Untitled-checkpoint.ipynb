# %%
from Modules import wrist

# %%
wr1 = wrist.Wrist("rpf511", 4,'/dev/ttyACM0',9600)
# Out:
# ['loosen', '0.0', '0.0', '0.0', '0.0']
# ['paper', '652.32', '665.24', '768.46', '350.82']

# %%
while True:
    print(wr1.listen())
# Out:
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# loosen
# ...
